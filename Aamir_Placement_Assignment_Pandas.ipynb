# %%
import pandas as pd

data_products = {
    'ProductID': ['P1001', 'P1002', 'P1003', 'P1004', 'P1005', 'P1006', 'P1007', 'P1008', 'P1009', 'P1010',
                  'P1011', 'P1012', 'P1013', 'P1014', 'P1015'],
    'ProductName': ['Widget', 'Gadget', 'WidgetPro', 'Gizmo', 'Doodad', 'Thingy', 'Doohickey', 'Gimmick', 'Contraption', 'Device',
                    'Mechanism', 'Apparatus', 'Implement', 'Tool', 'Instrument'],
    'Price': [25.50, 45.75, 55.00, 12.95, 8.50, 22.50, 3.75, 7.80, 10.00, 33.50,
              45.00, 12.00, 14.95, 21.75, 17.50]
}
products = pd.DataFrame(data_products)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
products.head()
# Out:
#   ProductID ProductName  Price
# 0     P1001      Widget  25.50
# 1     P1002      Gadget  45.75
# 2     P1003   WidgetPro  55.00
# 3     P1004       Gizmo  12.95
# 4     P1005      Doodad   8.50

# %%
data_sales = {
    'SaleID': list(range(101, 116)),
    'ProductID': ['P1001', 'P1003', 'P1002', 'P1005', 'P1001', 'P1006', 'P1007', 'P1008', 'P1009', 'P1004',
                  'P1010', 'P1011', 'P1013', 'P1014', 'P1015'],
    'Quantity': [3, 1, 2, 5, 10, 4, 2, 8, 1, 3, 7, 6, 3, 1, 2],
    'CustomerID': ['C001', 'C003', 'C002', 'C002', 'C001', 'C004', 'C005', 'C003', 'C005', 'C001',
                   'C002', 'C003', 'C004', 'C005', 'C001']
}
sales = pd.DataFrame(data_sales)

# %%
sales.head()
# Out:
#    SaleID ProductID  Quantity CustomerID
# 0     101     P1001         3       C001
# 1     102     P1003         1       C003
# 2     103     P1002         2       C002
# 3     104     P1005         5       C002
# 4     105     P1001        10       C001

# %%
data_customers = {
    'CustomerID': ['C001', 'C002', 'C003', 'C004', 'C005', 'C006', 'C007', 'C008', 'C009', 'C010',
                   'C011', 'C012', 'C013', 'C014', 'C015'],
    'CustomerName': ['Alpha Corp', 'Beta LLC', 'Gamma Inc', 'Delta Co', 'Epsilon Ltd', 'Zeta Inc', 'Eta LLC', 'Theta Corp', 'Iota PLC', 'Kappa LLC',
                     'Lambda Co', 'Mu Inc', 'Nu Ltd', 'Xi Corp', 'Omicron PLC'],
    'Location': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose',
                 'Austin', 'Jacksonville', 'Fort Worth', 'Columbus', 'Charlotte']
}
customers = pd.DataFrame(data_customers)

# %%
customers.head()
# Out:
#   CustomerID CustomerName     Location
# 0       C001   Alpha Corp     New York
# 1       C002     Beta LLC  Los Angeles
# 2       C003    Gamma Inc      Chicago
# 3       C004     Delta Co      Houston
# 4       C005  Epsilon Ltd      Phoenix

# %% [markdown]
# # **Tasks**

# %% [markdown]
# 1. **What is the total revenue generated by each customer?**

# %%
sales = sales.merge(products, on="ProductID")
sales["Revenue"] = sales["Quantity"] * sales["Price"]


total_revenue_by_customer = sales.groupby("CustomerID")["Revenue"].sum().reset_index()
total_revenue_by_customer
# Out:
#   CustomerID  Revenue
# 0       C001   405.35
# 1       C002   368.50
# 2       C003   387.40
# 3       C004   134.85
# 4       C005    39.25

# %%
sales.head()
# Out:
#    SaleID ProductID  Quantity CustomerID ProductName  Price  Revenue
# 0     101     P1001         3       C001      Widget  25.50     76.5
# 1     102     P1003         1       C003   WidgetPro  55.00     55.0
# 2     103     P1002         2       C002      Gadget  45.75     91.5
# 3     104     P1005         5       C002      Doodad   8.50     42.5
# 4     105     P1001        10       C001      Widget  25.50    255.0

# %% [markdown]
# 2. **Which product has the highest total sales revenue?**

# %%
highest_revenue_product = sales.groupby("ProductID")["Revenue"].sum().idxmax()
highest_revenue_product
# Out:
# 'P1001'

# %% [markdown]
# 3. **How many unique customers bought each product?**

# %%
unique_customers_per_product = sales.groupby("ProductID")["CustomerID"].nunique()
unique_customers_per_product
# Out:
# ProductID
# P1001    1
# P1002    1
# P1003    1
# P1004    1
# P1005    1
# P1006    1
# P1007    1
# P1008    1
# P1009    1
# P1010    1
# P1011    1
# P1013    1
# P1014    1
# P1015    1
# Name: CustomerID, dtype: int64

# %% [markdown]
# 4. **Which customer bought the most units of any single product in a transaction?**

# %%
most_units_customer = sales.loc[sales["Quantity"].idxmax(), ["CustomerID", "ProductID", "Quantity"]]
most_units_customer
# Out:
# CustomerID     C001
# ProductID     P1001
# Quantity         10
# Name: 4, dtype: object

# %% [markdown]
# 5. **What is the average price of the products purchased by each customer?**

# %%
avg_price_per_customer = sales.groupby("CustomerID")["Price"].mean()
avg_price_per_customer
# Out:
# CustomerID
# C001    20.362500
# C002    29.250000
# C003    35.933333
# C004    18.725000
# C005    11.833333
# Name: Price, dtype: float64

# %% [markdown]
# 6. **List all products bought by customers located in 'New York'.**

# %%
ny_customers = customers[customers["Location"] == "New York"]["CustomerID"]
ny_products = sales[sales["CustomerID"].isin(ny_customers)]["ProductName"].unique()
ny_products
# Out:
# array(['Widget', 'Gizmo', 'Instrument'], dtype=object)

# %% [markdown]
# 7. **Which location had the highest number of distinct products sold?**

# %%
sales_with_location = sales.merge(customers, on="CustomerID")

distinct_products_per_location = sales_with_location.groupby("Location")["ProductID"].nunique()
highest_product_location = distinct_products_per_location.idxmax()
print(highest_product_location)
# Out:
# Chicago

# %% [markdown]
# 8. **What is the total quantity of products sold in 'Los Angeles'?**

# %%
total_qty_la = sales_with_location[sales_with_location["Location"]== "Los Angeles"]["Quantity"].sum()
total_qty_la
# Out:
# 14

# %% [markdown]
# 9. **Identify the customer who has spent the most money on a single transaction.**

# %%
most_spend_money_cst = sales.loc[sales["Revenue"].idxmax(), ["CustomerID", "Revenue"]]
most_spend_money_cst
# Out:
# CustomerID     C003
# Revenue       270.0
# Name: 11, dtype: object

# %% [markdown]
# 10. **Which product is the most popular in terms of quantity sold?**

# %%
popular_product = sales.groupby("ProductID")["Quantity"].count().idxmax()
popular_product
# Out:
# 'P1001'

# %%
most_popular_product = sales.groupby("ProductID")["Quantity"].sum().idxmax()
most_popular_product
# Out:
# 'P1001'

# %% [markdown]
# 11. **How many transactions have occurred in each location?**

# %%
sales.head()

transactions_per_location = sales_with_location.groupby("Location")["SaleID"].count()
transactions_per_location
# Out:
# Location
# Chicago        3
# Houston        2
# Los Angeles    3
# New York       4
# Phoenix        3
# Name: SaleID, dtype: int64

# %% [markdown]
# 12. **What is the average number of items per transaction for each location?**

# %%
avg_tran_per_location = sales_with_location.groupby("Location")["Quantity"].mean()
avg_tran_per_location
# Out:
# Location
# Chicago        5.000000
# Houston        3.500000
# Los Angeles    4.666667
# New York       4.500000
# Phoenix        1.333333
# Name: Quantity, dtype: float64

# %% [markdown]
# 13. **Which customer has the widest variety of products purchased?**

# %%
widest_variety_customer = sales_with_location.groupby("CustomerID")["ProductID"].nunique().idxmax()
widest_variety_customer
# Out:
# 'C001'

# %% [markdown]
# 14. **For each product, how many transactions were above the average price of all products?**

# %%
avg_price = products["Price"].mean()
above_avg = sales[sales["Price"] > avg_price].groupby("ProductID")["SaleID"].count()
above_avg
# Out:
# ProductID
# P1001    2
# P1002    1
# P1003    1
# P1006    1
# P1010    1
# P1011    1
# Name: SaleID, dtype: int64

# %% [markdown]
# 15. **Which customer has never bought the same product twice?**

# %%
unique_product_customers = sales["CustomerID"][sales.groupby(["CustomerID", "ProductID"])["ProductID"].transform("count") == 1].unique()
unique_product_customers
# Out:
# array(['C003', 'C002', 'C004', 'C005', 'C001'], dtype=object)
